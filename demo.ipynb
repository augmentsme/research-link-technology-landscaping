# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import json
import pandas as pd
from pathlib import Path
from modeling.utils import load_taxonomy, load_extracted_keywords
from modeling.visualizations import plot_hierarchical_taxonomy_treemap
from inspect_ai.analysis import messages_df, samples_df, evals_df, events_df

# %%
logs_dir=Path("logs")

# %%
messages = messages_df(logs_dir)
evals = evals_df(logs_dir)
events = events_df(logs_dir)

# %%
extracted_keywords = load_extracted_keywords(logs_dir)

# %%
extracted_keywords
# Out:
# KeywordsExtractionOutput(keywords=['jellyfish bloom drivers', 'anthropogenic pressures', 'climate change resilience', 'pre-harvest sprouting', 'late-maturity amylase', 'wheat grain molecular physiology', 'superfluid vortex dynamics', 'quantum turbulence', 'multicomponent superfluids', 'health workforce migration policy', 'skilled migration trends', 'two-tier health workforce', 'platelet cryopreservation', 'blood storage deterioration', 'long-term platelet storage', 'cultural mediation in tourism', 'multisensory experience design', 'Antarctic tourism sustainability', 'quasiparticles in correlated quantum matter', 'trapped atoms quantum simulation', 'quantum data memory', 'electrocatalytic nitrogen reduction', 'nanostructured electrocatalysts', 'two-electrode nitrogen fixation', 'neuro-mechanobiology', 'mechanosensitive ion channels', 'proprioception', 'ensemble ocean modeling', 'climate change projections', 'eddy-resolving simulations', 'nanoscale geological repositories', 'Re-Os dati
# ...
